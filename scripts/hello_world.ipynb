# %% [markdown]
# # heading
# ## sub heading
# ### sub-sub heading
# #### sub-sub-sub heading
#
# bulleted list
#
# - micheal
# - tito
#
# numbered list
#
# 1. first
# 2. second
# 3. third
# 4. fourth
#
# this is a code block: 'python3 hello_world.py'

# %% [markdown]
# ### here is hello world in python

# %%
print('hello world')
print(7+9)
# Out:
# hello world
# 16
